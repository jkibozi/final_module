# %% [markdown]
# # INFO 3402 - Final Project
# [Jason Kibozi-Yocka](https://github.com/jkibozi)<br>
# University of Colorado Boulder<br>

# %%
# import libraries
import pandas as pd
import numpy as np
from datetime import datetime as dt

pd.options.display.max_columns = 100

# %% [markdown]
# ## Ceaning My Datasets

# %% [markdown]
# ### Dictionaries
# Here I created dictionaries that I will use to convert FARS numbers into their corresponding variable values. This will make the data more useful and readable.

# %%
# create a list of columns to keep
keepList = ['STATE','ST_CASE','VEH_NO','PER_NO','COUNTY','DAY','MONTH','HOUR','MINUTE','HARM_EV','SCH_BUS','MAKE',
            'MOD_YEAR','AGE','SEX','PER_TYP','INJ_SEV','DRINKING','DRUGS','HISPANIC','RACE','DEATH_MO','DEATH_DA',
            'DEATH_HR','DEATH_MN',]

# %%
# STATE
# create a dictionary that pairs state_numbers with their corresponding state_names

stateDict = {1: 'Alabama',        2:'Alaska',           4:'Arizona',        5:'Arkansas',         6:'California',
             8:'Colorado',        9:'Connecticut',      10:'Delaware',      11:'D.C.',            12:'Florida',
             13:'Georgia',        15:'Hawaii',          16:'Idaho',         17:'Illinois',        18:'Indiana',
             19:'Iowa',           20:'Kansas',          21:'Kentucky',      22:'Louisiana',       23:'Maine', 
             24:'Maryland',       25:'Massachusetts',   26:'Michigan',      27:'Minnesota',       28:'Mississippi',
             29:'Missouri',       30:'Montana',         31:'Nebraska',      32:'Nevada',          33:'New Hampshire',
             34:'New Jersey',     35:'New Mexico',      36:'New York',      37:'North Carolina',  38:'North Dakota',
             39:'Ohio',          40:'Oklahoma',        41:'Oregon',        42:'Pennsylvania',    43:'Puerto Rico',
             44:'Rhode Island',   45:'South Carolina',  46:'South Dakota',  47:'Tennessee',       48:'Texas',
             49:'Utah',           50:'Vermont',         51:'Virginia',      52:'Virgin Islands',  53:'Washington',
             54:'West Virginia',  55:'Wisconsin',       56:'Wyoming'}

# %%
# COUNTY
# create a dictionary that pairs county_numbers with their corresponding county_names

countyDict = {0:'N/A',  997:'Other',  998:'Not Reported',  999:'Unknown'}
# All other numbers are County FARS numbers

countyVals = list(countyDict.keys())

# %%
# MONTH
# create a dictionary that pairs month_numbers with their corresponding month_name

monthDict = {1:'January',    2:'February',   3:'March',  4:'April',      5:'May',
             6:'June',       7:'July',       8:'August', 9:'September',  10:'October',
             11:'November',  12:'December',  88:'N/A',   99: 'Unknown'}

# %%
# HARM_EV (Harmful Event)
# create a dictionary that pairs harmfulevent_numbers with their corresponding harmfulevent_names

harmDict = {1:'Rollover/Overturn',            2:'Fire/Explosion',                3:'Water Immersion',
            4:'Gas Inhalation',               51:'Jackknife',                    6:'Injury (Non-Collision)',
            44:'Pavevment Irregularity',      7:'Injury (Non-Collision)',        16:'Thrown/Falling Object',
            72:'Cargo Loss/Shift/Damage',     5:'Fell/Jumped from Vehicle',      12:'Collision (Motor Vehicle)',
            54:'Collision (Motor Vehicle)',   55:'Collision (Motor Vehicle)',    8:'Collision (Pedestrian)',
            9:'Collision (Pedalcyclist)',     10:'Collision (Railway Vehicle)',  74:'Collision (Road Vehicle on Rails)',
            11:'Collision (Live Animal)',                           49:'Collision (Ridden Animal/Animal-Drawn Vehicle)',
            18:'Collision (Other Unfixed Objects)',                 15:'Collision (Non-Motorist on Personal Conveyance)',
            14:'Collision (Parked Vehicle)',  45:'Collision (Working Vehicle)',  73:'Collison (Cargo from Other Vehicle)',
            91:'Collision (Unknown Object)',
            17:'Collision (Boulder)',         19:'Collision (Building)',         58:'Collision (Ground)',
            20:'Collision (Impact Attenuator/Crash Cushion)',       50:'Collision (Bridge Overhead Structure)',
            21:'Collision (Bridge Pier or Support)',                23:'Collision (Bridge Rail)',
            24:'Collision (Guardrail Face)',  52:'Collision (Guardrail End)',    25:'Collision (Concrete Traffic Barrier)',
            57:'Collision (Cable Barrier)',                         26:'Collision (Other Traffic Barrier)',
            59:'Collision (Traffic Sign Support)',                  46:'Collision (Traffic Signal Support)',
            30:'Collision (Utility Pole/Light Support)',            31:'Collision (Other Post, Other Pole, or Other Supports)',
            32:'Collision (Culvert)',         33:'Collision (Curb)',             34:'Collision (Ditch)',
            35:'Collision (Embankment)',      38:'Collision (Fence)',            39:'Collision (Wall)',
            40:'Collision (Fire Hydrant)',    41:'Collision (Shrubbery)',        42:'Collision (Tree)',
            48:'Collision (Snow Bank)',       53:'Collision (Mail Box)',         43:'Collision (Other Fixed Object)',
            93:'Collision (Unknown Fixed Object)',                  99:'Reported as Unknown'}

# %%
# SCH_BUS (School Bus)
# create a dictionary that pairs bus_bools with their corresponding bus_values

schoolbusDict = {0:'No',1:'Yes'}

# %%
# MAKE
# create a dictionary that pairs make_numbers with their corresponding make_names

makeDict = {1:'American Motors',                2:'Jeep/Kaiser-Jeep/Willys-Jeep',  3:'AM General',      6:'Chrysler',
            7:'Dodge',                          8:'Imperial',                      9:'Plymouth',        10:'Eagle',
            12:'Ford',                          13:'Lincoln',                      14:'Mercury',        18:'Buick/Opel',
            19:'Cadillac',                      20:'Chevrolet',                    21:'Oldsmobile',     22:'Pontiac',
            23:'GMC',                           24:'Saturn',                       25:'Grumman',        26:'Coda',
            29:'Other Domestic Manufacturers',  30:'Volkswagen',                   31:'Alfa Romeo',     32:'Audi',
            33:'Austin/Austin Healey',          34:'BMW',                          35:'Datsun/Nissan',  36:'Fiat',
            37:'Honda',                         38:'Isuzu',                        39:'Jaguar',         40:'Lancia',
            41:'Mazda',                         42:'Mercedes-Benz',                43:'MG',             44:'Peugeot',
            45:'Porsche',                       46:'Renault',                      47:'Saab',           48:'Subaru',
            49:'Toyota',                        50:'Triumph',                      51:'Volvo',          52:'Mitsubishi',
            53:'Suzuki',                        54:'Acura',                        55:'Hyundai',        56:'Merkur',
            57:'Yugo',                          58:'Infiniti',                     59:'Lexus',          60:'Diahatsu',
            61:'Sterling',                      62:'Land Rover',                   63:'Kia',            64:'Daewoo',
            65:'Smart',                         67:'Scion',                        69:'Other Import',   70:'BSA',
            71:'Ducati',                        72:'Harley-Davidson',              73:'Kawasaki',       74:'Moto-Guzzi',
            75:'Norton',                        76:'Yamaha',                       77:'Victory',        80:'Brockway',
            81:'Diamond Reo/Reo',               82:'Freightliner',                 83:'FWD',
            84:'International Harvester/Navistar',
            85:'Kenworth',                      86:'Mack',                         87:'Peterbilt',      88:'Iveco/Magirus',
            89:'White/Autocar White/GMC',       90:'Bluebird',                     91:'Eagle Coach',    92:'Gillig',
            93:'MCI',                           94:'Thomas Built',                 97:'Not Reported',   98:'Other Make',
            99:'Unknown Make'}

# %%
# SEX
# create a dictionary that pairs sex_numbers with their corresponding sex_names

sexDict = {1:'Male',2:'Female',8:'Not Reported',9:'Reported as Unknown'}

# %%
# PER_TYP (Person Type)
# create a dictionary that pairs persontype_numbers with their corresponding persontype_names

ptypeDict = {1:'Driver',2:'Passenger',3:'Occupant (Not In-Transport)',9:'Unknown'}

# %%
# INJ_SEV
# create a dictionary that pairs injuryseverity_numbers with their corresponding injuryseverity_names

injuryDict = {0:'No Apparent Injury',        1:'Possible Injury',  2:'Suspected Minor Injury',
              3:'Suspected Serious Injury',  4:'Fatal Injury',     5:'Injured, Severity Unknown',
              6:'Died Prior to Crash',       9:'Unknown/Not Reported'}

# %%
# DRINKING
# create a dictionary that pairs drinking_numbers with their corresponding drinking_values

drinkingDict = {0:'No',1:'Yes',8:'Not Reported',9:'Reported as Unknown'}

# %%
# DRUGS
# create a dictionary that pairs drug_numbers with their corresponding drug_values

drugsDict = {0:'No',1:'Yes',8:'Not Reported',9:'Reported as Unknown'}

# %%
# HISPANIC (Hispanic Origin)
# create a dictionary that pairs hispanicorigin_numbers with their corresponding hispanicorigin_names

hispanicDict = {0:'N/A',  1:'Mexican',   2:'Puerto Rican',  3:'Cuban',    4:'Central/South American',  5:'European Spanish',
                6:'Unspecified/Other',   7:'Non-Hispanic',  99:'Unknown'}

# %%
# RACE
# create a dictionary that pairs race_numbers with their corresponding race_names

raceDict = {0:'N/A',                                        1:'White',                    2:'Black',
            3:'American Indian/Alaska Native',              4:'Chinese',                  5:'Japanese',
            6:'Hawaiian/Part-Hawaiian',                     7:'Filipino',                 18:'Asian Indian',
            19:'Other Indian',                              28:'Korean',                  38:'Samoan',
            48:'Vietnamese',                                58:'Guamanian',               68:'Other Asian/Pacific Islander',
            78:'Asian or Pacific Islander (Non Specific)',  97:'Multiple Races (Mixed)',  98:'All Other Races',
            99:'Unknown'}

# %%
# relate columns to dictionaries
keepDict = {'STATE':stateDict,'COUNTY':countyDict,'MONTH':monthDict,'HARM_EV':harmDict,
            'SCH_BUS':schoolbusDict,'MAKE':makeDict,'SEX':sexDict,'PER_TYP':ptypeDict,'INJ_SEV':injuryDict,
            'DRINKING':drinkingDict,'DRUGS':drugsDict,'HISPANIC':hispanicDict,'RACE':raceDict}

# %% [markdown]
# ### Function
# Here I created a function that cleans all of my datsets.

# %%
# create a function that handles cleaning for FARS datasets
def cleanFARS(filename,year):
    # read in dataset as dataframe
    farsDF = pd.read_csv(filename)
    farsDF
    
    # drop unnecessary columns in dataframe
    dropList = list(farsDF.columns)
    for i in keepList:
        if i in dropList:
            dropList.remove(i)
    farsDF.drop(columns=dropList,inplace=True)
    
    
    
    # convert column codes to name values
    for col in list(keepDict.keys()):
        
        if col == 'COUNTY':
            farsDF[col].map(lambda x: countyDict[x] if x in countyVals else x)
        else:
            farsDF[col] = farsDF[col].map(keepDict[col])
            # https://stackoverflow.com/questions/20250771/remap-values-in-pandas-column-with-a-dict

            # drop rows in dataframe where column value contains NaN
            #farsDF.dropna(axis=0,subset=[col],inplace=True)
            farsDF.reset_index(drop=True,inplace=True)
    
    # combine 'DAY' and 'MONTH' into 'DATE' column
    dateList = []
    
    for i, row in farsDF.iterrows():
        date = str(row['MONTH'])+' '+str(row['DAY'])+', '+str(year)
        if '88' in date:
            dateList.append('N/A')
        elif '99' in date:
            dateList.append('Unknown')
        else:
            dateList.append(date)
    
    farsDF.drop(columns=['DAY','MONTH'],inplace=True)
    farsDF.insert(4, 'DATE',dateList,True)
    
    # combine 'HOUR' and 'MINUTE' into 'TIME' column
    timeList = []
    
    for i, row in farsDF.iterrows():
        if 'N/A' in str(row['DATE']) or 'Unknown' in str(row['DATE']):
            time = str(row['HOUR'])+':'+str(row['MINUTE'])
        else:
            time = str(row['DATE']) + ' ' + str(row['HOUR'])+':'+str(row['MINUTE'])
        if '88' in time:
            timeList.append('N/A')
        elif '99' in time:
            timeList.append('Unknown')
        else:
            timeList.append(time)
    
    farsDF.drop(columns=['HOUR','MINUTE'],inplace=True)
    farsDF.insert(5,'TIME',timeList,True)
    
    deathList = []
    for i, row in farsDF.iterrows():
        deathDay = str(row['DEATH_MO'])+' '+str(row['DEATH_DA'])+', '+str(year)
        deathTime = str(row['DEATH_HR'])+' '+str(row['DEATH_MN'])
        if '88' in deathDay:
            deathList.append('N/A')
        elif '99' in deathDay:
            deathList.append('Unknown')
        else:
            if '88' in deathTime or '99' in deathTime:
                deathList.append(deathDay)
            else:
                death = str(deathDay) + ' ' + str(deathTime)
                deathList.append(death)
    
    farsDF.drop(columns=['DEATH_MO','DEATH_DA','DEATH_HR','DEATH_MN'],inplace=True)
    farsDF.insert(0,'DEATH',timeList,True)
    
    # reorder columns
    farsDF = farsDF[['STATE','COUNTY','ST_CASE','DATE','TIME','VEH_NO','SCH_BUS','MAKE','MOD_YEAR','PER_NO','PER_TYP','AGE',
                     'SEX','RACE','HISPANIC','HARM_EV','INJ_SEV','DEATH','DRINKING','DRUGS']]
    
    return farsDF

myfiles = ['PERSON_2000','PERSON_2001','PERSON_2002','PERSON_2003','PERSON_2004','PERSON_2005','PERSON_2006','PERSON_2007',
         'PERSON_2008','PERSON_2009','PERSON_2010','PERSON_2011','PERSON_2012','PERSON_2013','PERSON_2014','PERSON_2015',
         'PERSON_2016','PERSON_2017','PERSON_2018']

# %%
mergedDF = pd.DataFrame(columns=['STATE','COUNTY','ST_CASE','DATE','TIME','VEH_NO','SCH_BUS','MAKE','MOD_YEAR','PER_NO',
                                 'PER_TYP','AGE','SEX','RACE','HISPANIC','HARM_EV','INJ_SEV','DEATH','DRINKING','DRUGS'])

for file in myfiles:
    myFile = file + '.csv'
    myYear = file[-4:]
    myDF = cleanFARS(myFile,myYear)
    myDF.to_csv('datasets\\'+myFile.lower(),index=False)
    mergedDF = mergedDF.append(myDF)
    print('Completed: '+myFile)
# Out:
# Completed: PERSON_2000.csv
# Completed: PERSON_2001.csv
# Completed: PERSON_2002.csv
# Completed: PERSON_2003.csv
# Completed: PERSON_2004.csv
# Completed: PERSON_2005.csv
# Completed: PERSON_2006.csv
# Completed: PERSON_2007.csv
# Completed: PERSON_2008.csv
# Completed: PERSON_2009.csv
# Completed: PERSON_2010.csv
# C:\Users\jkibo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3185: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# Completed: PERSON_2011.csv
# Completed: PERSON_2012.csv
# Completed: PERSON_2013.csv
# Completed: PERSON_2014.csv
# Completed: PERSON_2015.csv
# Completed: PERSON_2016.csv
# Completed: PERSON_2017.csv
# Completed: PERSON_2018.csv

# %%
mergedDF
# Out:
#          STATE COUNTY ST_CASE               DATE                     TIME  \
# 0      Alabama    117   10001    January 1, 2000     January 1, 2000 5:24
# 1      Alabama    117   10001    January 1, 2000     January 1, 2000 5:24
# 2      Alabama    117   10001    January 1, 2000     January 1, 2000 5:24
# 3      Alabama    117   10001    January 1, 2000     January 1, 2000 5:24
# 4      Alabama    117   10001    January 1, 2000     January 1, 2000 5:24
# 5      Alabama      1   10002    January 3, 2000    January 3, 2000 18:35
# 6      Alabama     73   10003    January 9, 2000     January 9, 2000 8:45
# 7      Alabama     21   10004    January 6, 2000     January 6, 2000 3:25
# 8      Alabama     53   10005    January 4, 2000     January 4, 2000 9:35
# 9      Alabama     53   10005    January 4, 2000     January 4, 2000 9:35
# 10     Alabama     53   10005    January 4, 2000     January 4, 2000 9:35
# 11     Alabama     97   10006    January 1, 2000    January 1, 2000 19:15
# ...

# %%
mergedDF.to_csv('datasets\\'+'person_all.csv',index=False)

# %% [markdown]
# ## Populating MySQL Database

# %%
# following code is based upon code provided by Prof. Brian C. Keegan, Ph.D.

from sqlalchemy import create_engine

host = 'localhost'
port = 3306
user = 'root'

with open('pass.txt','r') as file:
    password = file.readline()

database = 'fars'

engine = create_engine('mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}'.format(
    user,password,host,port,database),connect_args={'connect_timeout':1000})

conn = engine.connect()

# %%
# following code is based upon code provided by Prof. Brian C. Keegan, Ph.D.

import os

files = os.listdir('./datasets/')
csv_files = [f for f in files if '.csv' in f]
db_tables = pd.read_sql_query('show tables',conn)['Tables_in_fars'].tolist()

for f in csv_files:
    table_name = f.split('.csv')[0]
    
    if table_name not in db_tables:
        _df = pd.read_csv('./datasets/' + f)
        
        try:
            _df.to_sql(name = table_name,
                       con = conn,
                       schema='fars',
                       if_exists = 'replace',
                       index = False,
                       chunksize = 1000000)
        
        except:
            print(table_name)
            pass

# %%
# It worked, now my sql database is populated with tables
pd.read_sql_query('show tables',conn)
# Out:
#    Tables_in_fars
# 0     person_2000
# 1     person_2001
# 2     person_2002
# 3     person_2003
# 4     person_2004
# 5     person_2005
# 6     person_2006
# 7     person_2007
# 8     person_2008
# 9     person_2009
# 10    person_2010
# 11    person_2011
# 12    person_2012
# 13    person_2013
# 14    person_2014
# 15    person_2015
# 16    person_2016
# 17    person_2017
# 18    person_2018
# 19     person_all
